# %%
import os
import cv2
import numpy as np
import pandas as pd

from insightface.app import FaceAnalysis

# %%
faceapp = FaceAnalysis(name='buffalo_sc',
                      root='InsightFaceModels',
                      providers=['CPUExecutionProvider'])

faceapp.prepare(ctx_id=0, det_size=(640,640), det_thresh=0.5)
# Out:
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: InsightFaceModels\models\buffalo_sc\det_500m.onnx detection [1, 3, '?', '?'] 127.5 128.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: InsightFaceModels\models\buffalo_sc\w600k_mbf.onnx recognition ['None', 3, 112, 112] 127.5 127.5
# set det-size: (640, 640)

# %%
import re

# %%
def clean_name(string):
    string=re.sub(r'[^A-Za-z]',' ',string)
    string=string.title()
    return string

# %%
person_info=[]
listdir=os.listdir(path='images')
for folder_name in listdir:
    role, name= folder_name.split('-')
    name=clean_name(name)
    role=clean_name(role)
    #print('Role =',role,end='\t')
    #print('Name =',name)

    img_files=os.listdir(path=f'images/{folder_name}')
    for file in img_files:
        path=f'./images/{folder_name}/{file}'
        img_arr=cv2.imread(path)
        result = faceapp.get(img_arr,max_num=1)
        if len(result)>0:
            res=result[0]
            embedding = res['embedding']
            person_info.append([name,role,embedding])

# %%
dataframe=pd.DataFrame(person_info,columns=['Name','Role','Facial_Features'])
dataframe
# Out:
#                   Name     Role  \
# 0       Angelina Jolie  Student
# 1       Angelina Jolie  Student
# 2       Angelina Jolie  Student
# 3       Angelina Jolie  Student
# 4       Angelina Jolie  Student
# 5       Angelina Jolie  Student
# 6       Angelina Jolie  Student
# 7       Angelina Jolie  Student
# 8       Angelina Jolie  Student
# 9       Angelina Jolie  Student
# 10         Chris Evans  Student
# 11         Chris Evans  Student
# 12         Chris Evans  Student
# 13         Chris Evans  Student
# 14         Chris Evans  Student
# 15         Chris Evans  Student
# 16         Chris Evans  Student
# 17         Chris Evans  Student
# 18         Chris Evans  Student
# 19         Chris Evans  Student
# 20  Scarlett Johansson  Student
# 21  Scarlett Johansson  Student
# 22  Scarlett Johansson  Student
# 23  Scarlett Johansson  Student
# 24  Scarlett Johansson  Student
# 25  Scarlett Johansson  Student
# 26  Scarlett Johansson  Student
# 27  Scarlett Johansson  Student
# 28  Scarlett Johansson  Student
# 29  Scarlett Johansson  Student
# 30        Barack Obama  Teacher
# 31        Barack Obama  Teacher
# 32        Barack Obama  Teacher
# 33        Barack Obama  Teacher
# 34        Barack Obama  Teacher
# 35        Barack Obama  Teacher
# 36        Barack Obama  Teacher
# 37        Barack Obama  Teacher
# 38        Barack Obama  Teacher
# 39        Barack Obama  Teacher
# 40      Morgan Freeman  Teacher
# 41      Morgan Freeman  Teacher
# 42      Morgan Freeman  Teacher
# 43      Morgan Freeman  Teacher
# 44      Morgan Freeman  Teacher
# 45      Morgan Freeman  Teacher
# 46      Morgan Freeman  Teacher
# 47      Morgan Freeman  Teacher
# 48      Morgan Freeman  Teacher
# 49      Morgan Freeman  Teacher
#
#                                       Facial_Features
# 0   [-0.840976, 1.6623011, -0.74578035, -2.1380825...
# 1   [0.09012404, -0.4169108, -0.37650695, 0.424011...
# 2   [0.86389506, 0.32952017, 0.05781859, -1.453824...
# 3   [1.6611172, 1.1610862, -0.41079235, -2.6411536...
# 4   [0.864314, 0.9437618, 0.4265172, -1.1836909, -...
# 5   [0.41072488, 1.1821749, -0.9955386, -1.4014187...
# 6   [0.4228965, 2.084679, 1.0648315, -2.2739332, -...
# 7   [0.39441854, 0.844123, -0.6154812, -2.104783, ...
# 8   [1.0931159, 1.16805, -0.2896319, -2.0099528, -...
# 9   [-0.63542634, 1.7897139, 0.59832734, -3.550089...
# 10  [1.8046337, -2.301599, -1.5814648, -1.1037462,...
# 11  [1.7499522, -2.120638, -0.15303323, -0.9053567...
# 12  [0.44954258, -1.6314547, -0.95116156, -1.54259...
# 13  [0.8585786, -1.1000845, -0.7710812, -1.4918342...
# 14  [-1.1621715, -0.68589675, -0.43853605, -2.8765...
# 15  [0.35355112, -0.69770634, -0.30065766, -1.9116...
# 16  [1.3115609, -2.0907722, -1.0405229, -1.7980812...
# 17  [0.9714033, -1.7574674, -1.3090365, -1.0256081...
# 18  [0.5908869, -1.415056, -0.6726382, -1.310897, ...
# 19  [0.27377757, -0.8834741, -0.56312096, -0.63476...
# 20  [0.15676695, -0.15236786, -1.1744982, 0.222928...
# 21  [0.9988493, -0.3466223, -1.6070874, -0.3437251...
# 22  [0.41842282, -1.2317785, -1.1667099, 0.3219425...
# 23  [0.74071056, -0.2172078, -2.1699548, -0.382094...
# 24  [-0.29309803, -0.027716726, -3.063662, -0.0223...
# 25  [0.9100211, -0.7951274, -2.354409, 0.8837526, ...
# 26  [0.51819485, -0.70666325, -1.5376583, 0.951404...
# 27  [-0.97056913, -0.09710638, -2.1181054, 1.34236...
# 28  [0.879202, -0.5877949, 0.08335531, 0.654172, 0...
# 29  [-1.4453042, -0.7219956, -1.7936003, 0.79554, ...
# 30  [0.8677803, -0.26745942, 0.07078171, -0.144091...
# 31  [1.6967494, -0.99423915, -0.22416729, -1.75013...
# 32  [0.048347764, -0.4933409, -0.19507346, -1.1232...
# 33  [0.7236616, -0.9442341, -0.08801663, -2.404883...
# 34  [0.5904316, 0.43525362, 0.3595047, -2.803945, ...
# 35  [0.33019817, -1.278012, 0.40063405, -1.3588877...
# 36  [-0.06508007, 0.01565358, -0.85267746, -0.3290...
# 37  [2.277565, -1.3967812, 1.5635507, -1.4799635, ...
# 38  [1.6049532, -0.2434924, 0.36104548, 0.04073015...
# 39  [1.4112035, -0.4173997, -0.4473747, -1.4431926...
# 40  [0.5248391, -0.52419454, -0.51587707, 0.827002...
# 41  [0.79333276, -0.48215386, -1.7259705, 0.651349...
# 42  [-0.13147733, 0.04087484, 0.62813395, 0.683366...
# 43  [0.48640934, -0.4775918, -1.0033873, 1.2773727...
# 44  [1.2917784, -0.94640553, -0.1353631, 1.0459716...
# 45  [-0.27468443, -0.2753064, -0.84154445, 1.27969...
# 46  [0.7716732, -0.6371075, 0.1712926, 0.55135304,...
# 47  [1.2278079, -1.5642701, 0.42995828, 0.9718561,...
# 48  [-0.2606339, 0.020522118, -0.41956586, 1.67549...
# 49  [0.42446506, -1.3469219, -0.6576085, 1.7243186...

# %%
img_test=cv2.imread('test_images/test_2.jpeg')
cv2.imshow('test_image',img_test)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
res_test=faceapp.get(img_test,max_num=0)
for i,rt in enumerate(res_test):
    print('current loop = ',i)
    bbox=rt['bbox'].astype(int)
    score=int(rt['det_score']*100)
    embed_test=rt['embedding']
# Out:
# current loop =  0

# %%
len(embed_test)
# Out:
# 512

# %%
embed_test
# Out:
# array([-1.0794209 , -1.106817  , -1.2358055 , -1.1184733 ,  1.6912835 ,
#         1.2587602 , -0.42545304,  1.2529421 ,  1.9019961 ,  1.1875618 ,
#        -2.2458298 ,  2.0359764 , -0.16769719,  0.5307629 ,  0.30050385,
#        -0.21242332,  0.30540988, -1.0245438 ,  0.23911111,  1.2249293 ,
#        -0.31456357, -1.1223117 ,  2.434485  ,  1.0285479 ,  0.6132133 ,
#        -1.2184056 ,  1.4724448 , -0.37911248, -1.1318517 ,  1.2429032 ,
#         1.1630024 ,  0.4936406 ,  0.96875656,  0.03858541,  0.40804625,
#        -0.41315195,  0.0175181 ,  0.35681504,  0.91274524, -0.13435462,
#        -1.5694399 ,  1.4076433 ,  0.95215726, -0.38525414,  0.08780497,
#        -0.47189492, -0.20714593,  1.118402  ,  0.775218  , -0.74888206,
#        -2.0983334 ,  0.99330544, -1.8608006 , -2.0646064 , -0.8853907 ,
#        -0.03325728,  2.255765  ,  0.24467283, -0.39156628, -1.2572623 ,
#        -0.8227543 ,  0.22220078,  0.57083416,  0.37354052, -1.1787844 ,
#         0.8612194 ,  0.08324359,  0.71663344,  1.3165777 ,  0.48855394,
#        -0.19687623, -0.6693405 ,  0.13592505, -1.0342405 ,  0.88630915,
#        -1.057333  , -0.53558904, -0.81797445,  0.85930353,  0.48854136,
#        -1.6638864 ,  0.01644066, -1.2677435 , -0.96385527,  0.15102568,
#        -1.5199447 , -0.6395643 ,  0.02089423,  1.7619411 ,  0.4745984 ,
#         1.5968384 ,  0.79216105, -0.8250974 ,  1.1314516 ,  0.84722376,
#        -1.7831006 ,  0.86671376,  0.44064897, -0.7277204 ,  0.14235969,
#         1.6847367 ,  1.4358549 , -0.8035146 , -0.9785708 ,  0.12168306,
#        -1.178423  , -0.68381953, -0.9931849 ,  1.0326054 , -1.8023484 ,
#        -0.07332611,  0.2027264 ,  1.9346414 ,  2.2958453 , -0.6773338 ,
#        -0.50964123, -0.54627365, -1.2690132 ,  0.8324976 ,  1.2402672 ,
#        -0.90337753, -1.4634452 ,  0.62178373,  0.15959013, -0.0445509 ,
#        -0.39639425,  1.0544713 ,  0.04795578,  0.05715021,  0.8110658 ,
#        -0.29681885,  1.3418212 , -0.8092141 ,  0.9829465 , -1.3984532 ,
#         0.05228843,  0.3510661 ,  0.764749  , -0.4526924 , -0.45832756,
#        -1.2506323 , -0.74179065,  0.38086176, -0.10454541, -1.9319535 ,
#         1.1648014 ,  0.87736803, -1.919239  , -0.5034818 , -0.55874544,
#        -0.66803634,  0.19336742, -0.7839672 ,  1.2929499 , -1.5963812 ,
#        -0.6938597 , -0.24135077,  0.93378925, -1.3566675 , -0.22431043,
#        -0.03881925,  0.90869063,  0.9656602 , -0.4045272 , -1.5329802 ,
#        -0.5453782 , -0.13760555, -0.14504844,  0.45253503, -0.41379762,
#         0.10536627, -0.6295164 ,  0.08069795,  2.1044533 ,  1.3883469 ,
#         0.6270459 ,  0.56178945, -0.099298  , -0.710965  , -0.541756  ,
#        -0.583303  ,  0.72675335,  0.22981659,  0.6510566 , -0.5146702 ,
#        -0.850271  , -0.6567243 ,  0.7707702 ,  0.56649166, -0.54901576,
#        -1.5198729 ,  2.403039  ,  0.93104804, -0.7348509 ,  0.7839724 ,
#         1.4490203 ,  1.637853  , -0.57793534,  0.8652035 ,  0.30708146,
#        -0.39420503, -0.1571603 ,  0.5758008 ,  0.07824117, -0.6829664 ,
#        -1.0430417 , -0.95459837,  1.8444567 ,  0.8110931 ,  1.6689882 ,
#        -1.2515576 , -0.32475176,  0.33166623, -0.5161104 , -0.37665093,
#         0.8125087 , -0.2926824 , -1.0444895 ,  0.15489992, -0.6332921 ,
#        -0.10409316,  1.800554  , -1.154001  ,  1.8482976 ,  1.9412556 ,
#         0.42515144, -0.7642549 ,  0.10225755,  1.6062732 ,  0.6749506 ,
#         0.22931316, -1.057251  ,  0.8617715 ,  0.63238996, -0.62710845,
#        -1.8728763 , -0.87928176,  1.1218289 ,  0.539179  ,  0.9618989 ,
#        -0.00892982, -1.0843853 , -0.23545067, -0.7008668 , -1.5224992 ,
#         0.20674597, -0.44925874,  0.93119293,  1.0777595 , -2.0912306 ,
#         0.85571814, -0.8692684 ,  1.3713723 ,  0.87135136, -0.39878762,
#         1.0382841 , -0.00342023,  1.150425  , -0.84119666,  0.03170621,
#        -0.5426823 , -1.0531307 , -1.1586863 , -0.26374733,  0.3364085 ,
#        -2.2551205 , -0.4932674 , -0.0376454 ,  0.23594262, -0.03102928,
#         0.87827444,  0.67492753, -0.20254919, -0.18196921,  0.19972259,
#        -0.45754933,  1.6048309 ,  0.19026564,  0.06499219,  1.1347313 ,
#         0.6342978 ,  1.1965535 , -0.4713784 ,  1.6729575 ,  1.198532  ,
#         0.05192187,  1.2571034 ,  0.06338592,  0.30742994,  0.21583545,
#         0.02282131,  0.33632582,  0.00444221, -0.22221157, -0.08307451,
#         0.13153867,  1.8354304 ,  0.05383988, -0.17290853, -0.6640408 ,
#         0.2800306 ,  1.2362871 , -1.2588502 ,  1.8468266 , -0.45168245,
#        -0.03253618, -0.39902943,  0.6726371 , -1.0109619 ,  0.495156  ,
#        -1.3489293 , -0.60116   ,  0.03712404, -0.6319255 ,  0.14831959,
#        -0.477364  ,  0.36743307, -0.06023616,  1.4165714 , -0.06309438,
#        -0.76162016, -0.01509392,  0.91653156,  1.0660012 , -1.4544392 ,
#        -1.1711987 , -0.46073997, -0.79773605, -0.83444524,  0.01974517,
#         0.18770511, -1.2685633 ], dtype=float32)

# %%
X_list= dataframe['Facial_Features'].tolist()
X=np.asarray(X_list)

# %%
X.shape
# Out:
# (50, 512)

# %%
from sklearn.metrics import pairwise

# %%
y=embed_test.reshape(1,512)

equlidean_distance=pairwise.euclidean_distances(X,y)
manhattan_distance=pairwise.manhattan_distances(X,y)
cosine_similar=pairwise.cosine_similarity(X,y)

# %%
data_search=dataframe.copy()
data_search['equlidean'] = equlidean_distance
data_search['manhattan'] = manhattan_distance
data_search['cosine'] = cosine_similar

# %%
data_search
# Out:
#                   Name     Role  \
# 0       Angelina Jolie  Student
# 1       Angelina Jolie  Student
# 2       Angelina Jolie  Student
# 3       Angelina Jolie  Student
# 4       Angelina Jolie  Student
# 5       Angelina Jolie  Student
# 6       Angelina Jolie  Student
# 7       Angelina Jolie  Student
# 8       Angelina Jolie  Student
# 9       Angelina Jolie  Student
# 10         Chris Evans  Student
# 11         Chris Evans  Student
# 12         Chris Evans  Student
# 13         Chris Evans  Student
# 14         Chris Evans  Student
# 15         Chris Evans  Student
# 16         Chris Evans  Student
# 17         Chris Evans  Student
# 18         Chris Evans  Student
# 19         Chris Evans  Student
# 20  Scarlett Johansson  Student
# 21  Scarlett Johansson  Student
# 22  Scarlett Johansson  Student
# 23  Scarlett Johansson  Student
# 24  Scarlett Johansson  Student
# 25  Scarlett Johansson  Student
# 26  Scarlett Johansson  Student
# 27  Scarlett Johansson  Student
# 28  Scarlett Johansson  Student
# 29  Scarlett Johansson  Student
# 30        Barack Obama  Teacher
# 31        Barack Obama  Teacher
# 32        Barack Obama  Teacher
# 33        Barack Obama  Teacher
# 34        Barack Obama  Teacher
# 35        Barack Obama  Teacher
# 36        Barack Obama  Teacher
# 37        Barack Obama  Teacher
# 38        Barack Obama  Teacher
# 39        Barack Obama  Teacher
# 40      Morgan Freeman  Teacher
# 41      Morgan Freeman  Teacher
# 42      Morgan Freeman  Teacher
# 43      Morgan Freeman  Teacher
# 44      Morgan Freeman  Teacher
# 45      Morgan Freeman  Teacher
# 46      Morgan Freeman  Teacher
# 47      Morgan Freeman  Teacher
# 48      Morgan Freeman  Teacher
# 49      Morgan Freeman  Teacher
#
#                                       Facial_Features  equlidean   manhattan  \
# 0   [-0.840976, 1.6623011, -0.74578035, -2.1380825...  30.831608  550.446653
# 1   [0.09012404, -0.4169108, -0.37650695, 0.424011...  30.680958  555.258290
# 2   [0.86389506, 0.32952017, 0.05781859, -1.453824...  31.644897  574.439401
# 3   [1.6611172, 1.1610862, -0.41079235, -2.6411536...  31.804695  581.380992
# 4   [0.864314, 0.9437618, 0.4265172, -1.1836909, -...  31.845743  575.526853
# 5   [0.41072488, 1.1821749, -0.9955386, -1.4014187...  31.448256  563.773013
# 6   [0.4228965, 2.084679, 1.0648315, -2.2739332, -...  30.735941  559.293373
# 7   [0.39441854, 0.844123, -0.6154812, -2.104783, ...  30.919462  568.305766
# 8   [1.0931159, 1.16805, -0.2896319, -2.0099528, -...  32.054050  575.020484
# 9   [-0.63542634, 1.7897139, 0.59832734, -3.550089...  33.458736  599.186356
# 10  [1.8046337, -2.301599, -1.5814648, -1.1037462,...  25.619473  452.843931
# 47  [1.2278079, -1.5642701, 0.42995828, 0.9718561,...  31.848490  577.087057
# 48  [-0.2606339, 0.020522118, -0.41956586, 1.67549...  33.055401  603.478296
# 49  [0.42446506, -1.3469219, -0.6576085, 1.7243186...  33.980091  627.917390
#
#       cosine
# 0  -0.011336
# 1   0.018317
# 2  -0.009939
# 3   0.033799
# 4  -0.011627
# 5  -0.019591
# 6  -0.002086
# 7  -0.002109
# 8  -0.028779
# 9  -0.032620
# 10  0.386351
# 11  0.423303
# 12  0.430161
# 13  0.458633
# 14  0.360728
# 15  0.460120
# 16  0.466898
# 17  0.374399
# 18  0.495197
# 19  0.260266
# 20 -0.018098
# 21  0.003872
# 22 -0.013570
# 23  0.021144
# 24  0.092500
# 25  0.024957
# 26  0.058649
# 27  0.097580
# 28 -0.005943
# 29 -0.027222
# 30 -0.095825
# 31 -0.134648
# 32 -0.031112
# 33 -0.034401
# 34 -0.084581
# 35 -0.008367
# 36 -0.070025
# 37 -0.094142
# 38 -0.074596
# 39 -0.074989
# 40  0.096029
# 41  0.085428
# 42  0.040906
# 43  0.098152
# 44  0.067570
# 45  0.097881
# 46  0.084533
# 47  0.140487
# 48  0.120696
# 49  0.069182

# %%
d_eq_optimal=25 #450 for manhattan,0.5 for cosine

# %%
datafilter=data_search.query(f'equlidean<{d_eq_optimal}')
datafilter.reset_index(drop=True,inplace=True)

if len(datafilter)>0:
    argmin=datafilter['equlidean'].argmin()
    name, role=datafilter.loc[argmin][['Name','Role']]
else:
    name='Unknown'
    role='Unknown'

# %%
print(name,role)
# Out:
# Chris Evans Student

# %%
def ml_search_algorithm(dataframe,feature_column,test_vector,name_role=['Name','Role'],thresh=0.5):
    dataframe=dataframe.copy()
    X_list=dataframe[feature_column].tolist()
    x=np.asarray(X_list)
    
    similar=pairwise.cosine_similarity(x,test_vector.reshape(1,-1))
    similar_arr=np.array(similar).flatten()
    dataframe['cosine']=similar_arr

    data_filter=dataframe.query(f'cosine>={thresh}')
    if len(datafilter)>0:
        datafilter.reset_index(drop=True,inplace=True)
        argmax=datafilter['cosine'].argmax()
        person_name, person_role=datafilter.loc[argmax][name_role]
    else:
        name='Unknown'
        role='Unknown'

    return person_name, person_role

# %%
test_image=cv2.imread('test_images/test_11.jpg')
cv2.imshow('test image',test_image)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
results=faceapp.get(test_image)
test_copy=test_image.copy()

for res in results:
    x1, y1, x2, y2=res['bbox'].astype(int)
    embeddings=res['embedding']
    person_name, person_role = ml_search_algorithm(dataframe,
                                                   'Facial_Features',
                                                   test_vector=embeddings,
                                                   name_role=['Name','Role'],
                                                   thresh=0.5)
    cv2.rectangle(test_copy,(x1,y1),(x2,y2),(0,255,0))
    text_gen=person_name
    cv2.putText(test_copy,text_gen,(x1,y1),cv2.FONT_HERSHEY_DUPLEX,0.5,(0,255,0),1)
cv2.imshow('test image',test_copy)
cv2.waitKey()
cv2.destroyAllWindows()
    #print(person_name, person_role)
